# %%
import argparse
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.metrics import classification_report
from sklearn import cross_validation
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
# Out:
# /Users/hknam/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from utilities import visualize_classifier

# %%
def build_arg_parser():
    parser = argparse.ArgumentParser(description = 'Classification data using Ensemble Learning techniques')
    parser.add_argument('--classifier-type', dest = 'classifier_type',
    required = True, choices = ['rf', 'erf'], help = '''Type of Classifier to use; can be either 'rf ' or ''erf' ''')
    return parser

# %%
def random_forest(classifier_type):
    
    #args = build_arg_parser().parse_args()
    #classifier_type = args.classifier_type
        
    input_file = 'data_random_forests.txt'
    data = np.loadtxt('./data/' + input_file, delimiter = ',')
    X, y = data[:, :-1], data[:, -1]
    
    class_0 = np.array(X[y == 0])
    class_1 = np.array(X[y == 1])
    class_2 = np.array(X[y == 2])
    
    plt.figure()
    plt.scatter(class_0[:, 0], class_0[:, 1], s = 75, facecolors = 'white',
                edgecolors = 'black', linewidth = 1, marker = 's')
    plt.scatter(class_1[:, 0], class_1[:, 1], s = 75, facecolors = 'white',
                edgecolors = 'black', linewidth = 1, marker = 'o')
    plt.scatter(class_2[:, 0], class_2[:, 1], s = 75, facecolors = 'white',
                edgecolors = 'black', linewidth = 1, marker = '^')
    plt.title('Input data')
    
    X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y, test_size = 0.25, random_state =5)
    
    params = {'n_estimators' : 100, 'max_depth' : 4, 'random_state' : 0}
    
    if classifier_type == 'rf':
        classifier = RandomForestClassifier(**params)
    else:
        classifier = ExtraTreesClassifier(**params)
        
    classifier.fit(X_train, y_train)
    visualize_classifier(classifier, X_train, y_train, 'Training dataset')
    
    y_test_pred = classifier.predict(X_test)
    visualize_classifier(classifier, X_test, y_test, 'Test dataset')
    
    class_names = 'Class-0', 'Class-1', 'Class-2'
    print('#' * 40)
    print('Classifier performance on training dataset')
    print(classification_report(y_train, classifier.predict(X_train), target_names = class_names))
    print('#' * 40 + '\n')
    
    print('# 40')
    print('Classifier performance on test dataset')
    print(classification_report(y_test, y_test_pred, target_names = class_names))
    print('#' * 40)
    
    test_datapoint = np.array([[5,5], [3,6], [6,4], [7,2], [4,4], [5,2]])
    print('Confidence measure : ')
    
    for datapoint in test_datapoint:
        probabilities = classifier.predict_proba([datapoint])[0]
        predicted_class = 'Class-' + str(np.argmax(probabilities))
        print('Datapoint : ', datapoint)
        print('Probilities : ', probabilities)
        print('Predicted class : ', predicted_class)
        
    visualize_classifier(classifier, test_datapoint, [0] * len(test_datapoint), 'Test datapoints')
    plt.show()

# %%
def main():
    random_forest('rf')
    random_forest('erf')

# %%
if __name__ == '__main__':
    main()
# Out:
# ########################################
# Classifier performance on training dataset
#              precision    recall  f1-score   support
#
#     Class-0       0.91      0.86      0.88       221
#     Class-1       0.84      0.87      0.86       230
#     Class-2       0.86      0.87      0.86       224
#
# avg / total       0.87      0.87      0.87       675
#
# ########################################
#
# # 40
# Classifier performance on test dataset
#              precision    recall  f1-score   support
#
#     Class-0       0.92      0.85      0.88        79
#     Class-1       0.86      0.84      0.85        70
#     Class-2       0.84      0.92      0.88        76
#
# avg / total       0.87      0.87      0.87       225
#
# ########################################
# Confidence measure :
# Datapoint :  [5 5]
# Probilities :  [ 0.81427532  0.08639273  0.09933195]
# Predicted class :  Class-0
# Datapoint :  [3 6]
# Probilities :  [ 0.93574458  0.02465345  0.03960197]
# Predicted class :  Class-0
# Datapoint :  [6 4]
# Probilities :  [ 0.12232404  0.7451078   0.13256816]
# Predicted class :  Class-1
# Datapoint :  [7 2]
# Probilities :  [ 0.05415465  0.70660226  0.23924309]
# Predicted class :  Class-1
# Datapoint :  [4 4]
# Probilities :  [ 0.20594744  0.15523491  0.63881765]
# Predicted class :  Class-2
# Datapoint :  [5 2]
# Probilities :  [ 0.05403583  0.0931115   0.85285267]
# Predicted class :  Class-2
# ########################################
# Classifier performance on training dataset
#              precision    recall  f1-score   support
#
#     Class-0       0.89      0.83      0.86       221
#     Class-1       0.82      0.84      0.83       230
#     Class-2       0.83      0.86      0.85       224
#
# avg / total       0.85      0.85      0.85       675
#
# ########################################
#
# # 40
# Classifier performance on test dataset
#              precision    recall  f1-score   support
#
#     Class-0       0.92      0.85      0.88        79
#     Class-1       0.84      0.84      0.84        70
#     Class-2       0.85      0.92      0.89        76
#
# avg / total       0.87      0.87      0.87       225
#
# ########################################
# Confidence measure :
# Datapoint :  [5 5]
# Probilities :  [ 0.48904419  0.28020114  0.23075467]
# Predicted class :  Class-0
# Datapoint :  [3 6]
# Probilities :  [ 0.66707383  0.12424406  0.20868211]
# Predicted class :  Class-0
# Datapoint :  [6 4]
# Probilities :  [ 0.25788769  0.49535144  0.24676087]
# Predicted class :  Class-1
# Datapoint :  [7 2]
# Probilities :  [ 0.10794013  0.6246677   0.26739217]
# Predicted class :  Class-1
# Datapoint :  [4 4]
# Probilities :  [ 0.33383778  0.21495182  0.45121039]
# Predicted class :  Class-2
# Datapoint :  [5 2]
# Probilities :  [ 0.18671115  0.28760896  0.52567989]
# Predicted class :  Class-2
